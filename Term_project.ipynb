# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler,MinMaxScaler,MaxAbsScaler
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.svm import SVC
import csv

# %%
# 주어진 csv 데이터를 dataframe으로 불러온다.
data = pd.read_csv("lol_10mindata.csv",encoding='utf-8')
features = ['blueWardsPlaced', 'blueWardsDestroyed',
       'blueFirstBlood', 'blueKills', 'blueDeaths', 'blueAssists',
       'blueEliteMonsters', 'blueDragons', 'blueHeralds',
       'blueTowersDestroyed', 'blueTotalGold', 'blueAvgLevel',
       'blueTotalExperience', 'blueTotalMinionsKilled',
       'blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff',
       'blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed',
       'redFirstBlood', 'redKills', 'redDeaths', 'redAssists',
       'redEliteMonsters', 'redDragons', 'redHeralds', 'redTowersDestroyed',
       'redTotalGold', 'redAvgLevel', 'redTotalExperience',
       'redTotalMinionsKilled', 'redTotalJungleMinionsKilled', 'redGoldDiff',
       'redExperienceDiff', 'redCSPerMin', 'redGoldPerMin']
target = 'blueWins'
df.head()
data.hist(bins=20,figsize=(20,10))
plt.tight_layout()
plt.show()

# %%
# 스케일러를 적용하여 데이터의 크기를 맞춰준다.
scaler = StandardScaler()

X = data[features]
y = data[target]
X_scaled = scaler.fit_transform(data)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state = 30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # 스케일러를 적용하여 데이터의 크기를 맞춰준다.
#       2 scaler = StandardScaler()
# ----> 4 X = data[features]
#       5 y = data[target]
#       6 X_scaled = scaler.fit_transform(data)
#
# NameError: name 'data' is not defined

# %%
# k 최근접 이웃 분류

knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)

accuracy = knn.score(X_test,y_test)
error_rate = 1 - accuracy
print("Accuracy = ", accuracy)
print("Error rate = ",error_rate)

"""
model = make_pipeline(KNeighborsClassifier())
param_distrib = {'n_neighbors':np.arange(10,100,5)}
rnd_search = RandomizedSearchCV(model,param_distrib,n_iter=50,cv=3,scoring="accuracy",
                                random_state=42)
rnd_search.fit(X_train,y_train)
"""

# %%
# 소프트 벡터 머신 알고리즘
model_SVM = SVC(kernel = 'linear',C=1e10).fit(X_train,y_train)

# %%
# 결정 트리 알고리즘
model_tree = DecisionTreeClassifier(max_depth=10,random_state=40)
model_tree.fit(X_train,y_train)

plot.figure(figsize=(8,6))
plot_tree(model_tree,filled=True,features_names=features,class_names=target,rounded=True,fontsize=8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # 결정 트리 알고리즘
#       2 model_tree = DecisionTreeClassifier(max_depth=10,random_state=40)
# ----> 3 model_tree.fit(X_train,y_train)
#       5 plot.figure(figsize=(8,6))
#       6 plot_tree(model_tree,filled=True,features_names=features,class_names=target,rounded=True,fontsize=8)
#
# NameError: name 'X_train' is not defined
